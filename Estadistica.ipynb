# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Que idioma hablan en el hogar?
# Tabla de frecuencias
# Grafica de barras

# %%
df = pd.read_csv('sajquies.csv')
df.head()
# Out:
#    ID REDCAP  Comunidad ¿Accede a participar?  Informante: Nombre y Apellido  \
# 0          1  Sajquiyes                     Si           Maria Regina Xiquin
# 1          2  Sajquiyes                     Si                Cristina Iquic
# 2          3  Sajquiyes                     Si                    Eliseo Coc
# 3          4  Sajquiyes                     Si                 Martina Canel
# 4          5  Sajquiyes                     Si              Gilberto chamale
#
#   Rol en la Familia  ¿Qué idioma hablan en el hogar?  \t   (choice=Español)  \
# 0              Madre                                            Checked
# 1              Madre                                            Checked
# 2              Padre                                            Checked
# 3             Abuela                                            Checked
# 4              Padre                                            Checked
#
#   ¿Qué idioma hablan en el hogar?  \t   (choice=Kaqchiquel)  \
# ...

# %%
columna = df.iloc[:,5]
tabla_frecuencias = columna.value_counts()
print(tabla_frecuencias)
# Out:
# ¿Qué idioma hablan en el hogar?  \t   (choice=Español)
# Checked      191
# Unchecked     10
# Name: count, dtype: int64
