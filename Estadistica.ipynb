# %%
import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt

# %%
# Obtiene los datos del archivo csv
dfDatos = pd.read_csv('sajquies.csv')
dfDatos.head()
# Out:
#    ID REDCAP  Comunidad ¿Accede a participar?  Informante: Nombre y Apellido  \
# 0          1  Sajquiyes                     Si           Maria Regina Xiquin
# 1          2  Sajquiyes                     Si                Cristina Iquic
# 2          3  Sajquiyes                     Si                    Eliseo Coc
# 3          4  Sajquiyes                     Si                 Martina Canel
# 4          5  Sajquiyes                     Si              Gilberto chamale
#
#   Rol en la Familia  ¿Qué idioma hablan en el hogar?  \t   (choice=Español)  \
# 0              Madre                                            Checked
# 1              Madre                                            Checked
# 2              Padre                                            Checked
# 3             Abuela                                            Checked
# 4              Padre                                            Checked
#
#   ¿Qué idioma hablan en el hogar?  \t   (choice=Kaqchiquel)  \
# ...

# %% [markdown]
# - Que idioma hablan en el hogar?
# - Tabla de frecuencias
# - Grafica de barras

# %%
col1Datos = dfDatos.iloc[:,6]
objTablaFrecuencias = col1Datos.value_counts()
print(objTablaFrecuencias)
# Out:
# ¿Qué idioma hablan en el hogar?  \t   (choice=Kaqchiquel)
# Checked      139
# Unchecked     62
# Name: count, dtype: int64

# %%
dfDatos.iloc[:,6].value_counts()[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='¿Qué idioma hablan en el hogar?  \x7f\t   (choice=Kaqchiquel)'>
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 127 () missing from current font.
#   func(*args, **kwargs)
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
